# %% [markdown]
# # Gemini API Basics (via OpenAI SDK)
#
# In this notebook, I explore how to:
# - Load API keys securely using `.env`
# - Connect to Google Gemini via OpenAI-compatible API
# - Generate responses using chat completion
#
# This is part of my LLM Engineering learning journey.

# %%
import os
from dotenv import load_dotenv

from openai import OpenAI

# %%
load_dotenv(override=True)

google_api_key = os.getenv("GOOGLE_API_KEY")

if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith("AIz"):
    print("An API key was found, but it doesn't start AIz")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role": "user", "content": "Tell me a shocking scientific fact"}])

response.choices[0].message.content
# Out:
# "Here's a shocking scientific fact that often catches people off guard:\n\n**There are more trees on Earth than stars in the Milky Way galaxy.**\n\nLet's break down why this is shocking:\n\n*   **Scale of the Universe:** We tend to think of stars as incredibly vast and numerous, and our galaxy is immense. The Milky Way is estimated to contain between 100 billion and 400 billion stars.\n*   **Scale of Earth:** Trees are something we see every day, part of our familiar environment. It's hard to conceive of such a massive quantity of them.\n*   **The Numbers:** Current estimates suggest there are roughly **3 trillion trees** on Earth.\n\n**Why is this so surprising?**\n\nIt highlights how interconnected and surprisingly abundant life can be on our own planet, even when compared to the seemingly limitless expanse of the cosmos. It also underscores the importance of these natural systems for our own survival."

# %%
prompts = [
    "Tell me a shocking fact",
    "Tell me a shocking fact in 1 sentence",
    "Tell me a shocking fact like a professor",
]

for p in prompts:
    response = gemini.chat.completions.create(
        model="gemini-2.5-flash-lite",
        messages=[{"role": "user", "content": p}]
    )
    print(f"\nPrompt: {p}")
    print(response.choices[0].message.content)
# Out:
# Prompt: Tell me a shocking fact
# Here's a shocking fact for you:
#
# **Every single year, humans produce enough plastic waste to circle the Earth four times.**
#
# Think about that for a moment. The sheer volume of discarded plastic is staggering and has profound environmental consequences.
#
# Prompt: Tell me a shocking fact in 1 sentence
# The average person will swallow about 8 spiders in their lifetime while sleeping.
#
# Prompt: Tell me a shocking fact like a professor
# Alright, settle in. Today, we're going to delve into a corner of the universe that will undoubtedly redefine your perception of scale and perhaps even reality itself. Forget the grand pronouncements of cosmic expansion, the mind-bending nature of quantum entanglement, or the eerie silence of interstellar space. We're going to talk about something far more immediate, far more fundamental, and frankly, quite disquieting.
#
# ...

# %%
#Reusable Function 
def ask_gemini(prompt):
    response = gemini.chat.completions.create(
        model="gemini-2.5-flash-lite",
        messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content

ask_gemini("Explain Transformers simp
